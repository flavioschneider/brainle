# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join('..')))
import warnings
warnings.filterwarnings('ignore')

from typing import List
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import numpy as np
import matplotlib.pyplot as plt
import pytorch_lightning as pl
from torch import Tensor, einsum
from einops import parse_shape, rearrange, repeat
from PIL import Image

def count_parameters(model: nn.Module):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
import gym
from gym_miniworld import envs 

env = envs.Maze(
    obs_width=256,
    obs_height=256,
)
#env = gym.make('MiniWorld-Maze-v0')
env.seed(42)
num_actions = env.action_space.n

print(num_actions)

obs = env.reset()

for i in range(10):
    obs, reward, done, info = env.step(1)
    plt.imshow(Image.fromarray(obs))
    plt.show()
# Out:
# 2022-03-17 14:21:56.682 Python[31167:11809229] ApplePersistenceIgnoreState: Existing state will not be touched. New state will be written to /var/folders/64/x32rfnbd78n2jj1z9x_tgx9h0000gn/T/org.python.python.savedState
# Falling back to num_samples=4
# Falling back to non-multisampled frame buffer
# Falling back to num_samples=4
# Falling back to non-multisampled frame buffer
# 3

# %%
import gym_unrealcv
env = gym.make('UnrealSearch-RealisticRoomDoor-DiscreteColor')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [5], in <module>
#       1 import gym_unrealcv
# ----> 2 env = gym.make('UnrealSearch-RealisticRoomDoor-DiscreteColor')
#
# File ~/Documents/brainle/venv/lib/python3.9/site-packages/gym/envs/registration.py:676, in make(id, **kwargs)
#     675 def make(id: str, **kwargs) -> "Env":
# --> 676     return registry.make(id, **kwargs)
#
# File ~/Documents/brainle/venv/lib/python3.9/site-packages/gym/envs/registration.py:520, in EnvRegistry.make(self, path, **kwargs)
#     518 spec = self.spec(path)
#     519 # Construct the environment
# --> 520 return spec.make(**kwargs)
#
# File ~/Documents/brainle/venv/lib/python3.9/site-packages/gym/envs/registration.py:140, in EnvSpec.make(self, **kwargs)
#     138 else:
#     139     cls = load(self.entry_point)
# --> 140     env = cls(**_kwargs)
#     142 # Make the environment aware of which spec it came from.
#     143 spec = copy.deepcopy(self)
#
# File ~/Documents/brainle/gym-miniworld/gym-unrealcv/gym_unrealcv/envs/unrealcv_search_base.py:48, in UnrealCvSearch_base.__init__(self, setting_file, category, reset_type, augment_env, action_type, observation_type, reward_type, docker, resolution)
#      45 self.augment_env = augment_env
#      47 # start unreal env
# ---> 48 self.unreal = env_unreal.RunUnreal(ENV_BIN=setting['env_bin'])
#      49 env_ip, env_port = self.unreal.start(docker, resolution)
#      51 # connect UnrealCV
#
# File ~/Documents/brainle/gym-miniworld/gym-unrealcv/gym_unrealcv/envs/utils/env_unreal.py:18, in RunUnreal.__init__(self, ENV_BIN, ENV_MAP)
#      16 self.path2binary = os.path.abspath(os.path.join(self.path2env, self.env_bin))
#      17 self.path2unrealcv = os.path.join(os.path.split(self.path2binary)[0], 'unrealcv.ini')
# ---> 18 assert os.path.exists(self.path2binary), \
#      19     'Please load env binary in UnrealEnv and Check the env_bin in setting file!'
#
# AssertionError: Please load env binary in UnrealEnv and Check the env_bin in setting file!
